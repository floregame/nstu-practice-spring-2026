# %%
import numpy as np

a = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([5, 6, 7])

result = np.dot(a, b)

# %%
print(result)
# Out:
# [38 92]

# %%
a = np.array([1, 2, 3, 4, 5])

# %%
print(np.mean(a))
# Out:
# 3.0

# %%
arr = np.array([1, 5, 10, 15, 20])
clip = np.clip(arr, 5, 15)

# %%
print(clip)
# Out:
# [ 5  5 10 15 15]
